# %% [markdown]
# # Ejercicios Pandas
#
# En esta sección exploraremos un set de datos ficticio de de clientes de una aseguradora. El objetivo es contestar a las preguntas, mismas que estarán marcadas en **negritas**.
#
# Es importante mencionar que las preguntas tienen más de una solución posible, y al igual que en los ejercicios anteriores, la dificultad irá aumentando a medida que vayan progresando en los ejercicios.
#
# ### 1. importa pandas y numpy

# %%
# Tu código aquí

# %% [markdown]
# ### 2. Importa el DataFrame dentro de una variable
#
# * Nombre del archivo: direct_insurance.csv
# * Ruta del archivo: \Data
#
# hint: En caso de UnicodeDecodeError el parámetro `encoding` podría brindar una solución.

# %%
df = # Tu código aquí

# %% [markdown]
# ### 3. ¿Cuántas columnas y filas tiene el DataFrame?

# %%
# Tu código aquí

# %% [markdown]
# ### 4. ¿Cuál es el valor promedio y desviación estándar del campo `Prima_Seguros`?

# %%
# Tu código aquí

# %% [markdown]
# ### 5. ¿Cuáles son los valores máximos y mínimos de `Prima_Seguros`?

# %%
# Tu código aquí

# %%
# Tu código aquí

# %% [markdown]
# ### 6. El 90% de los valores dentro del campo `Prima_Seguros` se encuentran por debajo de qué valor

# %%
# Tu código aquí

# %% [markdown]
# Pregunta abiert: Viéndo los anteriores valores ¿Qué podríamos concluir? En caso de querer realizar un modelo ¿Qué supuesto de distribución estadística podría ser válido?

# %%
# Tu código aquí

# %% [markdown]
# ### 7. ¿Qué % de clientes tiene Estado Civil = Soltero?

# %%
# Tu código aquí

# %% [markdown]
# ### 8. ¿Cuántas personas tienen la palabra `"abogado"` (sin importar mayúsculas o minúsculas) en el campo `Trabajo`?

# %%
# Tu código aquí

# %% [markdown]
# ### 9. ¿Cual es el nivel de actividad de compra mas frecuente?

# %%
# Tu código aquí

# %% [markdown]
# ### 10. Analisis por region: calcula promedio de Numero_Siniestros, mediana de Ingreso_Anual, moda de Tipo_Vehiculo por cada region

# %%
# Tu código aquí
